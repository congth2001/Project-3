# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('../data/final.csv')
df
# Out:
#           Tournament                         Club            Player  Number  \
# 0             Laliga                   Ca Osasuna              Nano    23.0
# 1             Laliga                 Rcd Mallorca  Alejandro Alfaro    32.0
# 2         Bundesliga          Bayer 04 Leverkusen          Paulinho    15.0
# 3     Premier League                 Fc Liverpool           Fabinho     3.0
# 4            Serie A                Chievo Verona   Mamadou Samassa    30.0
# ...              ...                          ...               ...     ...
# 3480          Laliga  Real Sociedad San Sebastian  Robin Le Normand    24.0
# 3481          Laliga  Real Sociedad San Sebastian     Ander Guevara    16.0
# 3482          Laliga                Fc Villarreal   Alfonso Pedraza    24.0
# 3483          Laliga  Real Sociedad San Sebastian       Jon Pacheco    20.0
# 3484          Laliga  Real Sociedad San Sebastian  Andoni Gorosabel    18.0
#
#             Date  Market_value  Nation Pos     Position  Age  ...  \
# 0     2018-05-30         50000  es ESP  FW      Forward   25  ...
# 1     2019-09-10        300000  es ESP  CM   Midfielder   20  ...
# 2     2022-11-09       7000000  br BRA  LM   Midfielder   29  ...
# 3     2022-11-03      55000000  br BRA  CM   Midfielder   28  ...
# 4     2020-02-11        100000  ml MLI  GK  Goal Keeper   27  ...
# ...          ...           ...     ...  ..          ...  ...  ...
# 3480  2022-11-07      35000000  fr FRA  CB     Defender   25  ...
# 3481  2022-11-07       5000000  es ESP  CB     Defender   25  ...
# 3482  2022-11-07      18000000  es ESP  LB     Defender   26  ...
# 3483  2022-11-07       6000000  es ESP  CB     Defender   21  ...
# 3484  2022-11-07      10000000  es ESP  RB     Defender   26  ...
#
#       Passes_through_balls  Passes_Switches  Passes_crosses  \
# 0                 0.000000         0.000000        0.000000
# 1                 0.000000         0.000000        0.000000
# 2                 0.058824         0.058824        0.088235
# 3                 0.122699         0.288344        0.239264
# 4                 0.000000         0.000000        0.000000
# ...                    ...              ...             ...
# 3480              0.008621         0.284483        0.025862
# 3481              0.059701         0.208955        0.074627
# 3482              0.025806         0.109677        2.909677
# 3483              0.000000         0.285714        0.047619
# 3484              0.010204         0.020408        1.908163
#
#       Passes_throw-Ins_taken  Corner_kicks  Corner_Kicks_In  Corner_Kicks_Out  \
# 0                   0.100000      0.000000         0.000000          0.000000
# 1                   0.000000      0.000000         0.000000          0.000000
# 2                   0.088235      0.000000         0.000000          0.000000
# 3                   0.147239      0.000000         0.000000          0.000000
# 4                   0.000000      0.000000         0.000000          0.000000
# ...                      ...           ...              ...               ...
# 3480                0.103448      0.000000         0.000000          0.000000
# 3481                0.029851      0.000000         0.000000          0.000000
# 3482                4.890323      0.006452         0.000000          0.006452
# 3483                0.238095      0.000000         0.000000          0.000000
# 3484                7.653061      0.040816         0.010204          0.030612
#
#       Corner_Kicks_Straight  Passes_offside  Passes_blocked
# 0                       0.0        0.100000        0.500000
# 1                       0.0        0.000000        0.000000
# 2                       0.0        0.147059        0.500000
# 3                       0.0        0.098160        0.472393
# 4                       0.0        0.238095        0.000000
# ...                     ...             ...             ...
# 3480                    0.0        0.112069        0.224138
# 3481                    0.0        0.179104        0.567164
# 3482                    0.0        0.154839        1.716129
# 3483                    0.0        0.190476        0.285714
# 3484                    0.0        0.112245        0.979592
#
# [3485 rows x 91 columns]

# %%
forwarders = df[df['Position']=='Forward']
midfielders = df[df['Position']=='Midfielder']
defenders = df[df['Position']=='Defender']
goalkeepers = pd.read_csv('../data/final_gk.csv')

# %%
df[df['Position']=='Forward'].iloc[:,12:32].hist(figsize=(34, 34), bins='auto')
# Out:
# array([[<AxesSubplot: title={'center': 'Assists'}>,
#         <AxesSubplot: title={'center': 'Penalty_Kick_Made'}>,
#         <AxesSubplot: title={'center': 'Penalty_Kick_Attempted'}>,
#         <AxesSubplot: title={'center': 'Shots_total_not_penalty'}>],
#        [<AxesSubplot: title={'center': 'Shots_on_target'}>,
#         <AxesSubplot: title={'center': 'Yellow_cards'}>,
#         <AxesSubplot: title={'center': 'Red_cards'}>,
#         <AxesSubplot: title={'center': 'Touches'}>],
#        [<AxesSubplot: title={'center': 'Tackles'}>,
#         <AxesSubplot: title={'center': 'Interceptions'}>,
#         <AxesSubplot: title={'center': 'Performance_Blocks'}>,
#         <AxesSubplot: title={'center': 'Expected_goals'}>],
#        [<AxesSubplot: title={'center': 'Expected_non_penalty'}>,
#         <AxesSubplot: title={'center': 'Expected_assist_goals'}>,
#         <AxesSubplot: title={'center': 'Shot_create_actions'}>,
#         <AxesSubplot: title={'center': 'Goal_create_actions'}>],
#        [<AxesSubplot: title={'center': 'Passes_completed'}>,
#         <AxesSubplot: title={'center': 'Passes_attempted'}>,
#         <AxesSubplot: title={'center': 'Passes_completion%'}>,
#         <AxesSubplot: title={'center': 'Passes_progressive'}>]],
#       dtype=object)

# %%
forwards = df[df['Position']=='Forward']
midfielders = df[df['Position']=='Midfielder']
defenders = df[df['Position']=='Defender']

# %%
fig, ax = plt.subplots(figsize=(22,15))

x_labels = list(dict(df['Position'].value_counts()).keys())
x_ticks = list(range(0,len(x_labels)))
y_values = [a for a in df['Position'].value_counts()]
y_ticks = list(range(20,max(y_values)+30,25))

ax.bar(x_ticks,y_values,0.5,color='green',edgecolor='black')

for i in range(len(x_ticks)):
  plt.text(i,y_values[i],y_values[i],fontsize=20)
  
ax.set_yticks(y_ticks)
ax.set_xticks(x_ticks)
ax.set_xticklabels(x_labels,fontsize=20)
ax.set_title('Player Count by Position',fontsize=40)
ax.set_xlabel('Position',fontsize=30)
ax.set_ylabel('Player Count',fontsize=30)
ax.set_facecolor('xkcd:ivory')

# %%
df=df.sort_values(by='Market_value', ascending=False)

# %%
fig, ax = plt.subplots(figsize=(22,15))

x_labels = [a for a in df['Player'][:25]]
x_ticks = range(0,(len(x_labels)))
y_values = [a for a in df['Market_value'][:25]]
y_ticks = list(range(10000000,(max(df['Market_value'])+5000000),10000000))
y_ticklabels = [f'£ {int(a/1000000)} Million' for a in y_ticks]


ax.bar(x_ticks,y_values,0.5,edgecolor='gold',color='darkblue')


ax.set_xticks(x_ticks)
ax.set_xticklabels(x_labels,rotation=60,fontsize=15)
ax.set_yticks(y_ticks)
ax.set_yticklabels(y_ticklabels,fontsize=15)
ax.set_ylabel('Price',fontsize=25)
ax.set_title('25 Most Valuable Players',fontsize=30)
ax.set_facecolor('xkcd:lavender')
# Out:
# /tmp/ipykernel_21736/1559258440.py:3: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   x_labels = [a for a in df['Player'][:25]]
# /tmp/ipykernel_21736/1559258440.py:5: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   y_values = [a for a in df['Market_value'][:25]]

# %%
fig, ax = plt.subplots(figsize=(22,15))
y_labels = list(dict(abs(forwarders.corr()['Market_value'].sort_values(ascending=False))[1:11]).keys())
y_ticks = list(range(0,len(y_labels)))
x_values = list(dict(abs(forwarders.corr()['Market_value'].sort_values(ascending=False))[1:11]).values())
x_ticks = [a/100 for a in list(range(0,(int(max(x_values)*100)+10),5))]

ax.barh(y_ticks,x_values,0.5,color='darkviolet')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xlabel('Absolute Correlation Value',fontsize=20)
ax.set_title('Top Predictors for Forwarders',fontsize=40)
ax.set_facecolor('xkcd:ivory')
# Out:
# /tmp/ipykernel_21736/1362656210.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   y_labels = list(dict(abs(forwarders.corr()['Market_value'].sort_values(ascending=False))[1:11]).keys())
# /tmp/ipykernel_21736/1362656210.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   x_values = list(dict(abs(forwarders.corr()['Market_value'].sort_values(ascending=False))[1:11]).values())

# %%
fig, ax = plt.subplots(figsize=(22,15))
y_labels = list(dict(abs(midfielders.corr()['Market_value'].sort_values(ascending=False))[1:11]).keys())
y_ticks = list(range(0,len(y_labels)))
x_values = list(dict(abs(midfielders.corr()['Market_value'].sort_values(ascending=False))[1:11]).values())
x_ticks = [a/100 for a in list(range(0,(int(max(x_values)*100)+10),5))]

ax.barh(y_ticks,x_values,0.5,color='darkviolet')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xlabel('Absolute Correlation Value',fontsize=20)
ax.set_title('Top Predictors for Midfielders',fontsize=40)
ax.set_facecolor('xkcd:ivory')
# Out:
# /tmp/ipykernel_21736/1984774959.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   y_labels = list(dict(abs(midfielders.corr()['Market_value'].sort_values(ascending=False))[1:11]).keys())
# /tmp/ipykernel_21736/1984774959.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   x_values = list(dict(abs(midfielders.corr()['Market_value'].sort_values(ascending=False))[1:11]).values())

# %%
fig, ax = plt.subplots(figsize=(22,15))
y_labels = list(dict(abs(defenders.corr()['Market_value'].sort_values(ascending=False))[1:11]).keys())
y_ticks = list(range(0,len(y_labels)))
x_values = list(dict(abs(defenders.corr()['Market_value'].sort_values(ascending=False))[1:11]).values())
x_ticks = [a/100 for a in list(range(0,(int(max(x_values)*100)+10),5))]

ax.barh(y_ticks,x_values,0.5,color='darkviolet')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xlabel('Absolute Correlation Value',fontsize=20)
ax.set_title('Top Predictors for Defenders',fontsize=40)
ax.set_facecolor('xkcd:ivory')
# Out:
# /tmp/ipykernel_21736/3226003804.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   y_labels = list(dict(abs(defenders.corr()['Market_value'].sort_values(ascending=False))[1:11]).keys())
# /tmp/ipykernel_21736/3226003804.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   x_values = list(dict(abs(defenders.corr()['Market_value'].sort_values(ascending=False))[1:11]).values())

# %%
fig, ax = plt.subplots(figsize=(22,15))
y_labels = list(dict(abs(goalkeepers.corr()['Market_value'].sort_values(ascending=False))[1:11]).keys())
y_ticks = list(range(0,len(y_labels)))
x_values = list(dict(abs(goalkeepers.corr()['Market_value'].sort_values(ascending=False))[1:11]).values())
x_ticks = [a/100 for a in list(range(0,(int(max(x_values)*100)+10),5))]

ax.barh(y_ticks,x_values,0.5,color='darkviolet')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xlabel('Absolute Correlation Value',fontsize=20)
ax.set_title('Top Predictors for Goalkeepers',fontsize=40)
ax.set_facecolor('xkcd:ivory')
# Out:
# /tmp/ipykernel_21736/3569709811.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   y_labels = list(dict(abs(goalkeepers.corr()['Market_value'].sort_values(ascending=False))[1:11]).keys())
# /tmp/ipykernel_21736/3569709811.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   x_values = list(dict(abs(goalkeepers.corr()['Market_value'].sort_values(ascending=False))[1:11]).values())
