# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://fbref.com/en/comps/8/schedule/Champions-League-Scores-and-Fixtures"
data = requests.get(url)
soup = BeautifulSoup(data.text, 'html.parser')
for href in soup.find_all("a"):
  if href.text == "Previous Season":
    preSs = href
    break

"https://fbref.com" + preSs.get('href')
# Out:
# 'https://fbref.com/en/comps/8/2021-2022/schedule/2021-2022-Champions-League-Scores-and-Fixtures'

# %%
import pandas as pd

# %%
df = pd.read_csv('result_matches123.csv', header=None)
# df=df.drop(df.columns[[1]], axis=1)
df.insert(7, "", "", True)
df.insert(9, "", "", True)
df
df.to_csv("result_matches123.csv", index=False, header=False)

# %%
df = pd.read_csv('result_matches.csv')
df
# Out:
#        Match ID Round    Wk  Day        Date   Time            Home   xG  \
# 0      e62f6e78   NaN   1.0  Fri  2022-08-05  20:00  Crystal Palace  1.2
# 1      6713c1dc   NaN   1.0  Sat  2022-08-06  12:30          Fulham  1.2
# 2      09d8a999   NaN   1.0  Sat  2022-08-06  15:00       Tottenham  1.5
# 3      1ac96eb4   NaN   1.0  Sat  2022-08-06  15:00   Newcastle Utd  1.7
# 4      82702941   NaN   1.0  Sat  2022-08-06  15:00    Leeds United  0.8
# ...         ...   ...   ...  ...         ...    ...             ...  ...
# 25770  34d90cf6   NaN  18.0  Sun  2023-01-29  15:30          Vizela  1.6
# 25771  b38d1f16   NaN  18.0  Sun  2023-01-29  15:30        Casa Pia  1.3
# 25772  64786d8b   NaN  18.0  Sun  2023-01-29  18:00        Boavista  2.0
# 25773  7eb69bc6   NaN  18.0  Sun  2023-01-29  20:30       Famalicão  1.3
# 25774  ad26bff3   NaN  18.0  Mon  2023-01-30  20:15         Vitória  1.9
#
#       Score  xG.1             Away Attendance                          Venue  \
# ...
